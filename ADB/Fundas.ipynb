# %% [markdown]
# # Databricks Fundamentals
# Core concepts and essential operations for working with Spark and Databricks.

# %%
spark
# In Databricks, we get the spark object by default as a pre-initialized SparkSession.

# %%
# %sql
SELECT * FROM learn_adb.default.movies;

# %%
df = spark.table('learn_adb.default.movies')
display(df)

# %%
df.show(10)  # Display first 10 rows

# %%
df.printSchema()  # Display column names and data types

# %%
df.count()  # Get total number of rows
