# %%
from pyspark.sql import SparkSession

# %%
spark 
#in databricks we get the spark object by default

# %%
# %sql
select * from learn_adb.default.movies

# %%
df = spark.table('learn_adb.default.movies')
display(df)

# %%
#df.show()
df.show(10)

# %%
df.printSchema()

# %%
df.count()
